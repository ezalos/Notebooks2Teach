# %% [markdown]
# ___
#
# <a href='https://oxiane-institut.com/'> <img src='../oxiane.jpg' /></a>
# ___

# %%
import pandas as pd

# %% [markdown]
# ### From CSV

# %%
df_csv = pd.read_csv(
    "data/heart.csv",
    sep=",",                # For csv with a different separator
    header=0                # For csv without columns names
)

# Can be saved to csv with:
df_csv.to_csv(
    "data/my_data.csv",
    index=False             # index=False to avoid creating a new index each time
)

# %%
df_csv
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %%
out_csv_with_index = lambda n: f"data/heart_with_index_save_{n}.csv"
df_csv.to_csv(out_csv_with_index(0))

for i in range(2):
    df_with_index = pd.read_csv(out_csv_with_index(i))
    df_with_index.to_csv(out_csv_with_index(i + 1))
df_with_index
# Out:
#      Unnamed: 0.1  Unnamed: 0  age      sexe type_douleur  pression  \
# 0               0           0   70  masculin            D       130
# 1               1           1   67   feminin            C       115
# 2               2           2   57  masculin            B       124
# 3               3           3   64  masculin            D       128
# 4               4           4   74   feminin            B       120
# ..            ...         ...  ...       ...          ...       ...
# 265           265         265   52  masculin            C       172
# 266           266         266   44  masculin            B       120
# 267           267         267   56   feminin            B       140
# 268           268         268   57  masculin            D       140
# 269           269         269   67  masculin            D       160
#
#      cholester sucre electro  taux_max angine  depression  pic vaisseau  \
# 0          322     A       C       109    non          24    2        D
# 1          564     A       C       160    non          16    2        A
# 2          261     A       A       141    non           3    1        A
# 3          263     A       A       105    oui           2    2        B
# 4          269     A       C       121    oui           2    1        B
# ..         ...   ...     ...       ...    ...         ...  ...      ...
# 265        199     B       A       162    non           5    1        A
# 266        263     A       A       173    non           0    1        A
# 267        294     A       C       153    non          13    2        A
# 268        192     A       A       148    non           4    2        A
# 269        286     A       C       108    oui          15    2        D
#
#         coeur
# 0    presence
# 1     absence
# 2    presence
# 3     absence
# 4     absence
# ..        ...
# 265   absence
# 266   absence
# 267   absence
# 268   absence
# 269  presence
#
# [270 rows x 15 columns]

# %% [markdown]
# ### From excel

# %%
df_excel = pd.read_excel("data/Excel_Sample.xlsx", sheet_name="Sheet1")
df_excel
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df_excel.to_excel("data/Excel_Sample_2.xlsx", sheet_name="Sheet1")

# %% [markdown]
# ### From html

# %%
df = pd.read_html("http://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
df[0]
# Out:
#                                Bank Name               City          State  \
# 0  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
# 1                          Citizens Bank           Sac City           Iowa
# 2               Heartland Tri-State Bank            Elkhart         Kansas
# 3                    First Republic Bank      San Francisco     California
# 4                         Signature Bank           New York       New York
# 5                    Silicon Valley Bank        Santa Clara     California
# 6                      Almena State Bank             Almena         Kansas
# 7             First City Bank of Florida  Fort Walton Beach        Florida
# 8                   The First State Bank      Barboursville  West Virginia
# 9                     Ericson State Bank            Ericson       Nebraska
#
#     Cert                 Aquiring Institution       Closing Date   Fund
# 0  27332    Fulton Bank, National Association     April 26, 2024  10546
# 1   8758            Iowa Trust & Savings Bank   November 3, 2023  10545
# 2  25851               Dream First Bank, N.A.      July 28, 2023  10544
# 3  59017            JPMorgan Chase Bank, N.A.        May 1, 2023  10543
# 4  57053                  Flagstar Bank, N.A.     March 12, 2023  10540
# 5  24735  First Citizens Bank & Trust Company     March 10, 2023  10539
# 6  15426                          Equity Bank   October 23, 2020  10538
# 7  16748            United Fidelity Bank, fsb   October 16, 2020  10537
# 8  14361                       MVB Bank, Inc.      April 3, 2020  10536
# 9  18265           Farmers and Merchants Bank  February 14, 2020  10535

# %% [markdown]
# ### From parquet
#
# An excellent data format for big data.
#
# 1. Open-source
#
# 2. Columnar
#
#    ![](https://miro.medium.com/v2/resize:fit:720/format:webp/1*QEQJjtnDb3JQ2xqhzARZZw.png)
#
# 3. Performance:
#
#    It's possible to idependantly access any column without loading the full file
#
# 4. Compression on disk:
#
# 	Less storage needs, saved as binary file on disk
#
# 5. Self-describing:
#
#    Parquet file contains metadata including schema and structure.
#
#    Make it easier to decouple services that write, store, and read Parquet files.
#
#    ![](https://www.upsolver.com/wp-content/uploads/2020/05/Screen-Shot-2020-05-26-at-17.53.13-1024x532.png)
#
# .

# %%
df_csv.to_parquet(
    "./data/heart.parquet",
    index=False,
)

df_parquet = pd.read_parquet("./data/heart.parquet")
df_parquet
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %% [markdown]
# ### From SQL

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///data/heart.sqlite', echo=True)
df_sql = pd.read_sql(
    "SELECT * FROM heart;",
    engine
)
print("Done!\n\n")

engine = create_engine('sqlite:///:memory:', echo=True)
nb_lines_uploaded = df_sql.to_sql(
    "new_table",
    engine,
    index=False,
    method="multi",     # Create one INSERT statement by row
)
nb_lines_uploaded
# Out:
# 2024-09-24 00:13:09,880 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-24 00:13:09,881 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM heart;")
# 2024-09-24 00:13:09,881 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-24 00:13:09,882 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM heart;")
# 2024-09-24 00:13:09,883 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-24 00:13:09,884 INFO sqlalchemy.engine.Engine SELECT * FROM heart;
# 2024-09-24 00:13:09,884 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-24 00:13:09,887 INFO sqlalchemy.engine.Engine ROLLBACK
# Done!
#
#
# 2024-09-24 00:13:09,888 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-24 00:13:09,891 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("new_table")
# 2024-09-24 00:13:09,892 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-24 00:13:09,893 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("new_table")
# 2024-09-24 00:13:09,893 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-24 00:13:09,895 INFO sqlalchemy.engine.Engine
# CREATE TABLE new_table (
# 	id BIGINT,
# 	age BIGINT,
# 	sexe TEXT,
# 	type_douleur TEXT,
# 	pression BIGINT,
# 	cholester BIGINT,
# 	sucre TEXT,
# 	electro TEXT,
# 	taux_max BIGINT,
# 	angine TEXT,
# 	depression BIGINT,
# 	pic BIGINT,
# 	vaisseau TEXT,
# 	coeur TEXT
# )
#
#
# 2024-09-24 00:13:09,896 INFO sqlalchemy.engine.Engine [no key 0.00061s] ()
# 2024-09-24 00:13:09,941 INFO sqlalchemy.engine.Engine INSERT INTO new_table (id, age, sexe, type_douleur, pression, cholester, sucre, electro, taux_max, angine, depression, pic, vaisseau, coeur) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ? ...
# 2024-09-24 00:13:09,942 INFO sqlalchemy.engine.Engine [no key 0.00570s] (0, 70, 'masculin', 'D', 130, 322, 'A', 'C', 109, 'non', 24, 2, 'D', 'presence', 1, 67, 'feminin', 'C', 115, 564, 'A', 'C', 160, 'non', 16, 2, 'A', 'absence', 2, 57, 'masculin', 'B', 124, 261, 'A', 'A', 141, 'non', 3, 1, 'A', 'presence', 3, 64, 'masculin', 'D', 128, 263, 'A', 'A' ... 3680 parameters truncated ... 'A', 'A', 173, 'non', 0, 1, 'A', 'absence', 267, 56, 'feminin', 'B', 140, 294, 'A', 'C', 153, 'non', 13, 2, 'A', 'absence', 268, 57, 'masculin', 'D', 140, 192, 'A', 'A', 148, 'non', 4, 2, 'A', 'absence', 269, 67, 'masculin', 'D', 160, 286, 'A', 'C', 108, 'oui', 15, 2, 'D', 'presence')
# 2024-09-24 00:13:09,945 INFO sqlalchemy.engine.Engine COMMIT
# 270

# %%
df_sql
# Out:
#       id  age      sexe type_douleur  pression  cholester sucre electro  \
# 0      0   70  masculin            D       130        322     A       C
# 1      1   67   feminin            C       115        564     A       C
# 2      2   57  masculin            B       124        261     A       A
# 3      3   64  masculin            D       128        263     A       A
# 4      4   74   feminin            B       120        269     A       C
# ..   ...  ...       ...          ...       ...        ...   ...     ...
# 265  265   52  masculin            C       172        199     B       A
# 266  266   44  masculin            B       120        263     A       A
# 267  267   56   feminin            B       140        294     A       C
# 268  268   57  masculin            D       140        192     A       A
# 269  269   67  masculin            D       160        286     A       C
#
#      taux_max angine  depression  pic vaisseau     coeur
# 0         109    non          24    2        D  presence
# 1         160    non          16    2        A   absence
# 2         141    non           3    1        A  presence
# 3         105    oui           2    2        B   absence
# 4         121    oui           2    1        B   absence
# ..        ...    ...         ...  ...      ...       ...
# 265       162    non           5    1        A   absence
# 266       173    non           0    1        A   absence
# 267       153    non          13    2        A   absence
# 268       148    non           4    2        A   absence
# 269       108    oui          15    2        D  presence
#
# [270 rows x 14 columns]

# %% [markdown]
# ### Chunk size

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///data/heart.sqlite', echo=False)

for df_part in pd.read_sql("SELECT * FROM heart;", engine, chunksize=100):
    print(f"{df_part.shape = }")
# Out:
# df_part.shape = (100, 14)
# df_part.shape = (100, 14)
# df_part.shape = (70, 14)

# %% [markdown]
# ## Import netCDF

# %%
import xarray as xr

ds = xr.open_dataset("data/sresa1b_ncar_ccsm3-example.nc", decode_times=False)
df = ds.to_dataframe()
df
# Out:
#                                                     area  lat_bnds  \
# lat        lon       bnds plev     time
# -88.927734 0.00000   0    100000.0 730135.5  473460608.0     -90.0
#                           92500.0  730135.5  473460608.0     -90.0
#                           85000.0  730135.5  473460608.0     -90.0
#                           70000.0  730135.5  473460608.0     -90.0
#                           60000.0  730135.5  473460608.0     -90.0
# ...                                                  ...       ...
#  88.927734 358.59375 1    7000.0   730135.5  473460608.0      90.0
#                           5000.0   730135.5  473460608.0      90.0
#                           3000.0   730135.5  473460608.0      90.0
#                           2000.0   730135.5  473460608.0      90.0
#                           1000.0   730135.5  473460608.0      90.0
#
#                                                lon_bnds  msk_rgn        pr  \
# lat        lon       bnds plev     time
# -88.927734 0.00000   0    100000.0 730135.5   -0.703125        0  0.000001
#                           92500.0  730135.5   -0.703125        0  0.000001
#                           85000.0  730135.5   -0.703125        0  0.000001
#                           70000.0  730135.5   -0.703125        0  0.000001
#                           60000.0  730135.5   -0.703125        0  0.000001
# ...                                                 ...      ...       ...
#  88.927734 358.59375 1    7000.0   730135.5  359.296875        0  0.000011
#                           5000.0   730135.5  359.296875        0  0.000011
#                           3000.0   730135.5  359.296875        0  0.000011
#                           2000.0   730135.5  359.296875        0  0.000011
#                           1000.0   730135.5  359.296875        0  0.000011
#
#                                                     tas  time_bnds        ua
# lat        lon       bnds plev     time
# -88.927734 0.00000   0    100000.0 730135.5  215.893494   730120.0       NaN
#                           92500.0  730135.5  215.893494   730120.0       NaN
#                           85000.0  730135.5  215.893494   730120.0       NaN
#                           70000.0  730135.5  215.893494   730120.0       NaN
#                           60000.0  730135.5  215.893494   730120.0 -0.703753
# ...                                                 ...        ...       ...
#  88.927734 358.59375 1    7000.0   730135.5  265.429474   730151.0  5.400330
#                           5000.0   730135.5  265.429474   730151.0  5.053610
#                           3000.0   730135.5  265.429474   730151.0  4.340384
#                           2000.0   730135.5  265.429474   730151.0  3.787834
#                           1000.0   730135.5  265.429474   730151.0  2.631976
#
# [1114112 rows x 8 columns]

# %% [markdown]
# ## Import hdf5

# %%
df = pd.read_csv("data/heart.csv")

df.to_hdf("data/heart.h5", key="df", mode="w")

pd.read_hdf("data/heart.h5", key="df")
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]
