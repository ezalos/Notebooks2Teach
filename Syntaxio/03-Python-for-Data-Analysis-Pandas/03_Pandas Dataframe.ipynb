# %% [markdown]
# ___
#
# <a href='https://oxiane-institut.com/'> <img src='../oxiane.jpg' /></a>
# ___

# %% [markdown]
# ## Dataframe
#
#
# DataFrames are the cornerstone of pandas and are directly inspired by the R programming language.
#
# We can think of a DataFrame as a collection of Series objects grouped together to share the same index.
#
# Let's use pandas to explore this topic!

# %%
import pandas as pd
import numpy as np


pd.set_option(
    'display.max_colwidth', 100     # Default: 50
)

pd.set_option(
    'display.max_rows', 100         # Default: 15
)

# vérifier la version
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### From Python data

# %%
"A B C D E".split()
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
from numpy.random import randn

np.random.seed(101)

data = randn(5, 4)
indices = ['A', 'B', 'C', 'D', 'E']
colonnes = ['W', 'X', 'Y', 'Z']


df = pd.DataFrame(data, index=indices, columns=colonnes)
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ### Let's load a more complete dataset, from CSV

# %%
df = pd.read_csv("data/heart.csv")

# %%
# vérifions le type de df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (270, 13)

# %%
df.head()
# Out:
#    age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0   70  masculin            D       130        322     A       C       109
# 1   67   feminin            C       115        564     A       C       160
# 2   57  masculin            B       124        261     A       A       141
# 3   64  masculin            D       128        263     A       A       105
# 4   74   feminin            B       120        269     A       C       121
#
#   angine  depression  pic vaisseau     coeur
# 0    non          24    2        D  presence
# 1    non          16    2        A   absence
# 2    non           3    1        A  presence
# 3    oui           2    2        B   absence
# 4    oui           2    1        B   absence

# %%
df.columns
# Out:
# Index(['age', 'sexe', 'type_douleur', 'pression', 'cholester', 'sucre',
#        'electro', 'taux_max', 'angine', 'depression', 'pic', 'vaisseau',
#        'coeur'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age              int64
# sexe            object
# type_douleur    object
# pression         int64
# cholester        int64
# sucre           object
# electro         object
# taux_max         int64
# angine          object
# depression       int64
# pic              int64
# vaisseau        object
# coeur           object
# dtype: object

# %%
df
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %% [markdown]
# ## Indexing // accessing the data

# %% [markdown]
# ### Single column

# %%
df['sexe']
# Out:
# 0      masculin
# 1       feminin
# 2      masculin
# 3      masculin
# 4       feminin
#          ...
# 265    masculin
# 266    masculin
# 267     feminin
# 268    masculin
# 269    masculin
# Name: sexe, Length: 270, dtype: object

# %%
df.sexe
# Out:
# 0      masculin
# 1       feminin
# 2      masculin
# 3      masculin
# 4       feminin
#          ...
# 265    masculin
# 266    masculin
# 267     feminin
# 268    masculin
# 269    masculin
# Name: sexe, Length: 270, dtype: object

# %% [markdown]
# ### Multiple columns

# %%
df[["sexe", "age"]]

# ! /!\ it needs to be in an array
# df["sexe", "age"] # -> throws an error
# Out:
#          sexe  age
# 0    masculin   70
# 1     feminin   67
# 2    masculin   57
# 3    masculin   64
# 4     feminin   74
# ..        ...  ...
# 265  masculin   52
# 266  masculin   44
# 267   feminin   56
# 268  masculin   57
# 269  masculin   67
#
# [270 rows x 2 columns]

# %% [markdown]
# ### Create and delete columns

# %%
df["new_column"] = df["depression"] + df["pic"]
df
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur  new_column
# 0      non          24    2        D  presence          26
# 1      non          16    2        A   absence          18
# 2      non           3    1        A  presence           4
# 3      oui           2    2        B   absence           4
# 4      oui           2    1        B   absence           3
# ..     ...         ...  ...      ...       ...         ...
# 265    non           5    1        A   absence           6
# 266    non           0    1        A   absence           1
# 267    non          13    2        A   absence          15
# 268    non           4    2        A   absence           6
# 269    oui          15    2        D  presence          17
#
# [270 rows x 14 columns]

# %%
df.drop("new_column", axis=1)
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %%
# Not inplace unless specified!
df
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur  new_column
# 0      non          24    2        D  presence          26
# 1      non          16    2        A   absence          18
# 2      non           3    1        A  presence           4
# 3      oui           2    2        B   absence           4
# 4      oui           2    1        B   absence           3
# ..     ...         ...  ...      ...       ...         ...
# 265    non           5    1        A   absence           6
# 266    non           0    1        A   absence           1
# 267    non          13    2        A   absence          15
# 268    non           4    2        A   absence           6
# 269    oui          15    2        D  presence          17
#
# [270 rows x 14 columns]

# %%
df.drop("new_column", axis=1, inplace=True)
df
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %%
df.drop(0, axis=0)
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# 5     65  masculin            D       120        177     A       A       140
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# 5      non           4    1        A   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [269 rows x 13 columns]

# %% [markdown]
# ## Dataframe object

# %%
df_sorted_by_age = df.sort_values(by="age")

df_sorted_by_age.head()
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 214   29  masculin            B       130        204     A       C       202
# 174   34  masculin            A       118        182     A       C       174
# 138   34   feminin            B       118        210     A       A       192
# 224   35   feminin            D       138        183     A       A       182
# 81    35  masculin            D       120        198     A       A       130
#
#     angine  depression  pic vaisseau     coeur
# 214    non           0    1        A   absence
# 174    non           0    1        A   absence
# 138    non           7    1        A   absence
# 224    non          14    1        A   absence
# 81     oui          16    2        A  presence

# %%
df_reset_index = df_sorted_by_age.reset_index()
df_reset_index
# Out:
#      index  age      sexe type_douleur  pression  cholester sucre electro  \
# 0      214   29  masculin            B       130        204     A       C
# 1      174   34  masculin            A       118        182     A       C
# 2      138   34   feminin            B       118        210     A       A
# 3      224   35   feminin            D       138        183     A       A
# 4       81   35  masculin            D       120        198     A       A
# ..     ...  ...       ...          ...       ...        ...   ...     ...
# 265     15   71   feminin            D       112        149     A       A
# 266    255   71   feminin            B       160        302     A       A
# 267      4   74   feminin            B       120        269     A       C
# 268     73   76   feminin            C       140        197     A       B
# 269    199   77  masculin            D       125        304     A       C
#
#      taux_max angine  depression  pic vaisseau     coeur
# 0         202    non           0    1        A   absence
# 1         174    non           0    1        A   absence
# 2         192    non           7    1        A   absence
# 3         182    non          14    1        A   absence
# 4         130    oui          16    2        A  presence
# ..        ...    ...         ...  ...      ...       ...
# 265       125    non          16    2        A   absence
# 266       162    non           4    1        C   absence
# 267       121    oui           2    1        B   absence
# 268       116    non          11    2        A   absence
# 269       162    oui           0    1        D  presence
#
# [270 rows x 14 columns]

# %%
df_reset_index.rename(columns={"index": "old index"})
# Out:
#      old index  age      sexe type_douleur  pression  cholester sucre electro  \
# 0          214   29  masculin            B       130        204     A       C
# 1          174   34  masculin            A       118        182     A       C
# 2          138   34   feminin            B       118        210     A       A
# 3          224   35   feminin            D       138        183     A       A
# 4           81   35  masculin            D       120        198     A       A
# ..         ...  ...       ...          ...       ...        ...   ...     ...
# 265         15   71   feminin            D       112        149     A       A
# 266        255   71   feminin            B       160        302     A       A
# 267          4   74   feminin            B       120        269     A       C
# 268         73   76   feminin            C       140        197     A       B
# 269        199   77  masculin            D       125        304     A       C
#
#      taux_max angine  depression  pic vaisseau     coeur
# 0         202    non           0    1        A   absence
# 1         174    non           0    1        A   absence
# 2         192    non           7    1        A   absence
# 3         182    non          14    1        A   absence
# 4         130    oui          16    2        A  presence
# ..        ...    ...         ...  ...      ...       ...
# 265       125    non          16    2        A   absence
# 266       162    non           4    1        C   absence
# 267       121    oui           2    1        B   absence
# 268       116    non          11    2        A   absence
# 269       162    oui           0    1        D  presence
#
# [270 rows x 14 columns]

# %%
df_age_index = df_reset_index.set_index("age")
df_age_index
# Out:
#      index      sexe type_douleur  pression  cholester sucre electro  \
# age
# 29     214  masculin            B       130        204     A       C
# 34     174  masculin            A       118        182     A       C
# 34     138   feminin            B       118        210     A       A
# 35     224   feminin            D       138        183     A       A
# 35      81  masculin            D       120        198     A       A
# ..     ...       ...          ...       ...        ...   ...     ...
# 71      15   feminin            D       112        149     A       A
# 71     255   feminin            B       160        302     A       A
# 74       4   feminin            B       120        269     A       C
# 76      73   feminin            C       140        197     A       B
# 77     199  masculin            D       125        304     A       C
#
#      taux_max angine  depression  pic vaisseau     coeur
# age
# 29        202    non           0    1        A   absence
# 34        174    non           0    1        A   absence
# 34        192    non           7    1        A   absence
# 35        182    non          14    1        A   absence
# 35        130    oui          16    2        A  presence
# ..        ...    ...         ...  ...      ...       ...
# 71        125    non          16    2        A   absence
# 71        162    non           4    1        C   absence
# 74        121    oui           2    1        B   absence
# 76        116    non          11    2        A   absence
# 77        162    oui           0    1        D  presence
#
# [270 rows x 13 columns]

# %%
df_age_index.loc[71]
# Out:
#      index     sexe type_douleur  pression  cholester sucre electro  taux_max  \
# age
# 71      29  feminin            C       110        265     B       C       130
# 71      15  feminin            D       112        149     A       A       125
# 71     255  feminin            B       160        302     A       A       162
#
#     angine  depression  pic vaisseau    coeur
# age
# 71     non           0    1        B  absence
# 71     non          16    2        A  absence
# 71     non           4    1        C  absence
