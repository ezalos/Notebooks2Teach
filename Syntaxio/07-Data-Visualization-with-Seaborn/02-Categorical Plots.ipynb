# %% [markdown]
# ___
#
# <a href='https://oxiane-institut.com/'> <img src='../oxiane.jpg' /></a>
# ___

# %% [markdown]
# # Categorical Data Plots
#
# Let's now discuss using Seaborn to plot categorical data! There are several main types of plots for this:
#
# * factorplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
#
# Let's review examples of each!

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## barplot and countplot
#
# These very similar plots allow you to obtain aggregated data from a categorical feature of your data. **barplot** is a general graph that allows you to aggregate categorical data based on a function, by default the mean:

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %% [markdown]
# You can replace the estimator object with your own function that converts a vector to a scalar:

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### countplot
#
# This is essentially the same as the barplot, except that the estimator explicitly counts the number of occurrences. This is why we only pass the x value:

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Boxplot and Violinplot
#
# Boxplots and violinplots are used to show the distribution of categorical data.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be "outliers" using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="day", legend=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### violinplot
#
# A violin plot plays a similar role to a box and whisker plot.
#
# It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.
#
# Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.
#
# Note: When using violinplot, assign the x variable to hue and set legend=False instead of just passing palette.
#
# For example:
#
# `sns.violinplot(x="day", y="total_bill", data=tips, hue="day", palette='rainbow', legend=False)`
#
# This avoids the deprecation warning about passing palette without hue.

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue="day", palette='rainbow', legend=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## stripplot and swarmplot
#
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it also serves as a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don't overlap. This gives a better representation of the distribution of values, although it doesn't scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill",hue='sex',data=tips, palette="Set1")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Combining Categorical Plots

# %%
sns.violinplot(x="tip", y="day", data=tips, hue="day", palette='rainbow', legend=False)
sns.swarmplot(x="tip", y="day", data=tips, color='black', size=3)
# Out:
# <Axes: xlabel='tip', ylabel='day'>
