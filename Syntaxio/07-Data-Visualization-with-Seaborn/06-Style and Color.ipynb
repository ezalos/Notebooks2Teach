# %% [markdown]
# ___
#
# <a href='https://oxiane-institut.com/'> <img src='../oxiane.jpg' /></a>
# ___

# %% [markdown]
# Style and Color
#
# We have shown several times how to control the aesthetics of characters in Seaborn, but let's now examine it formally:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %% [markdown]
# ## Styles
#
# You can define specific styles:

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style('white')
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex', hue='sex', data=tips, palette='deep', legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(x='sex',data=tips)
sns.despine()

# %%
sns.countplot(x='sex',data=tips)
sns.despine(left=True)

# %% [markdown]
# ## Size and Aspect Ratio
#
# You can use **plt.figure(figsize=(width,height))** from matplotlib to modify the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing parameters: size and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',height=2,aspect=4,data=tips)

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override the default parameters:

# %%
sns.set_context('poster', font_scale=2)
sns.countplot(x='sex', data=tips, hue='sex', palette='coolwarm', legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# For more information on these topics, please consult the documentation page:
#
# https://stanford.edu/~mwaskom/software/seaborn/tutorial/aesthetics.html
