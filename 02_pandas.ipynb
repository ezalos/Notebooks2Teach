# %% [markdown]
# # Pandas
#
# Pandas
# - Lecture d’un fichier CSV
# - Lecture à partir d’une BDD
#
#
# TP Pandas
# - Lecture d’un fichier
# - Nettoyage des données
#
# De Pandas à Numpy
# - Différentes opérations de localisation et de regroupement par niveau
# - Obtenir les informations sur les dimensions, redimensionner une structure
# - Comprendre le broadcasting

# %%
import pandas as pd

pd.set_option(
    'display.max_colwidth', 100     # Default: 50
)

pd.set_option(
    'display.max_rows', 100         # Default: 15
)

#vérifier la version
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# ## First contact with a dataframe

# %%
# ✅
df = pd.read_csv("data/heart.csv")

# %%
# vérifions le type de df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# ✅
df.shape
# Out:
# (270, 13)

# %%
df.head()
# Out:
#    age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0   70  masculin            D       130        322     A       C       109
# 1   67   feminin            C       115        564     A       C       160
# 2   57  masculin            B       124        261     A       A       141
# 3   64  masculin            D       128        263     A       A       105
# 4   74   feminin            B       120        269     A       C       121
#
#   angine  depression  pic vaisseau     coeur
# 0    non          24    2        D  presence
# 1    non          16    2        A   absence
# 2    non           3    1        A  presence
# 3    oui           2    2        B   absence
# 4    oui           2    1        B   absence

# %%
df.columns
# Out:
# Index(['age', 'sexe', 'type_douleur', 'pression', 'cholester', 'sucre',
#        'electro', 'taux_max', 'angine', 'depression', 'pic', 'vaisseau',
#        'coeur'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age              int64
# sexe            object
# type_douleur    object
# pression         int64
# cholester        int64
# sucre           object
# electro         object
# taux_max         int64
# angine          object
# depression       int64
# pic              int64
# vaisseau        object
# coeur           object
# dtype: object

# %%
df
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %%
df.describe()
# Out:
#               age    pression   cholester    taux_max  depression         pic
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333  131.344444  249.659259  149.677778   10.500000    1.585185
# std      9.109067   17.861608   51.686237   23.165717   11.452098    0.614390
# min     29.000000   94.000000  126.000000   71.000000    0.000000    1.000000
# 25%     48.000000  120.000000  213.000000  133.000000    0.000000    1.000000
# 50%     55.000000  130.000000  245.000000  153.500000    8.000000    2.000000
# 75%     61.000000  140.000000  280.000000  166.000000   16.000000    2.000000
# max     77.000000  200.000000  564.000000  202.000000   62.000000    3.000000

# %%
df.describe(include='all')
# Out:
#                age      sexe type_douleur    pression   cholester sucre  \
# count   270.000000       270          270  270.000000  270.000000   270
# unique         NaN         2            4         NaN         NaN     2
# top            NaN  masculin            D         NaN         NaN     A
# freq           NaN       183          129         NaN         NaN   230
# mean     54.433333       NaN          NaN  131.344444  249.659259   NaN
# std       9.109067       NaN          NaN   17.861608   51.686237   NaN
# min      29.000000       NaN          NaN   94.000000  126.000000   NaN
# 25%      48.000000       NaN          NaN  120.000000  213.000000   NaN
# 50%      55.000000       NaN          NaN  130.000000  245.000000   NaN
# 75%      61.000000       NaN          NaN  140.000000  280.000000   NaN
# max      77.000000       NaN          NaN  200.000000  564.000000   NaN
#
#        electro    taux_max angine  depression         pic vaisseau    coeur
# count      270  270.000000    270  270.000000  270.000000      270      270
# unique       3         NaN      2         NaN         NaN        4        2
# top          C         NaN    non         NaN         NaN        A  absence
# freq       137         NaN    181         NaN         NaN      160      150
# mean       NaN  149.677778    NaN   10.500000    1.585185      NaN      NaN
# std        NaN   23.165717    NaN   11.452098    0.614390      NaN      NaN
# min        NaN   71.000000    NaN    0.000000    1.000000      NaN      NaN
# 25%        NaN  133.000000    NaN    0.000000    1.000000      NaN      NaN
# 50%        NaN  153.500000    NaN    8.000000    2.000000      NaN      NaN
# 75%        NaN  166.000000    NaN   16.000000    2.000000      NaN      NaN
# max        NaN  202.000000    NaN   62.000000    3.000000      NaN      NaN

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### From CSV

# %%
df_csv = pd.read_csv(
    "data/heart.csv",
    sep=",",                # For csv with a different separator
    header=0                # For csv without columns names
)

# Can be saved to csv with:
df_csv.to_csv(
    "data/my_data.csv",
    index=False             # index=False to avoid creating a new index each time
)

# %%
df_csv
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %%
out_csv_with_index = lambda n: f"data/heart_with_index_save_{n}.csv"
df_csv.to_csv(out_csv_with_index(0))

for i in range(2):
    df_with_index = pd.read_csv(out_csv_with_index(i))
    df_with_index.to_csv(out_csv_with_index(i + 1))
df_with_index
# Out:
#      Unnamed: 0.1  Unnamed: 0  age      sexe type_douleur  pression  \
# 0               0           0   70  masculin            D       130
# 1               1           1   67   feminin            C       115
# 2               2           2   57  masculin            B       124
# 3               3           3   64  masculin            D       128
# 4               4           4   74   feminin            B       120
# ..            ...         ...  ...       ...          ...       ...
# 265           265         265   52  masculin            C       172
# 266           266         266   44  masculin            B       120
# 267           267         267   56   feminin            B       140
# 268           268         268   57  masculin            D       140
# 269           269         269   67  masculin            D       160
#
#      cholester sucre electro  taux_max angine  depression  pic vaisseau  \
# 0          322     A       C       109    non          24    2        D
# 1          564     A       C       160    non          16    2        A
# 2          261     A       A       141    non           3    1        A
# 3          263     A       A       105    oui           2    2        B
# 4          269     A       C       121    oui           2    1        B
# ..         ...   ...     ...       ...    ...         ...  ...      ...
# 265        199     B       A       162    non           5    1        A
# 266        263     A       A       173    non           0    1        A
# 267        294     A       C       153    non          13    2        A
# 268        192     A       A       148    non           4    2        A
# 269        286     A       C       108    oui          15    2        D
#
#         coeur
# 0    presence
# 1     absence
# 2    presence
# 3     absence
# 4     absence
# ..        ...
# 265   absence
# 266   absence
# 267   absence
# 268   absence
# 269  presence
#
# [270 rows x 15 columns]

# %% [markdown]
# ✅
# ### From parquet
# 1. Columnar
#
#    ![](https://miro.medium.com/v2/resize:fit:720/format:webp/1*QEQJjtnDb3JQ2xqhzARZZw.png)
#
# 2. Open-source
#
# 3. Self-describing:
#
#    Parquet file contains metadata including schema and structure.
#
#    Make it easier to decouple services that write, store, and read Parquet files.
#
#    ![](https://www.upsolver.com/wp-content/uploads/2020/05/Screen-Shot-2020-05-26-at-17.53.13-1024x532.png)
#
# 4. Compression on disk
#
# 5. Performance:
#
#    It's possible to idependantly access any column without loading the full file

# %%
df_parquet = pd.read_parquet("./data/heart.parquet")

df_parquet.to_parquet(
    "./data/heart.parquet",
    index=False,
)
df_parquet
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 0      non          24    2        D  presence
# 1      non          16    2        A   absence
# 2      non           3    1        A  presence
# 3      oui           2    2        B   absence
# 4      oui           2    1        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence
#
# [270 rows x 13 columns]

# %% [markdown]
# ### From SQL

# %%
# ✅
from sqlalchemy import create_engine

engine = create_engine('sqlite:///data/heart.sqlite', echo=True)
df_sql = pd.read_sql(
    "SELECT * FROM heart;",
    engine
)
print("Done!\n\n")

engine = create_engine('sqlite:///:memory:', echo=True)
nb_lines_uploaded = df_sql.to_sql(
    "new_table",
    engine,
    index=False,
    method="multi",     # Create one INSERT statement by row
)
nb_lines_uploaded
# Out:
# 2024-04-26 22:04:35,284 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-04-26 22:04:35,285 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM heart;")
# 2024-04-26 22:04:35,286 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-26 22:04:35,288 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM heart;")
# 2024-04-26 22:04:35,289 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-26 22:04:35,291 INFO sqlalchemy.engine.Engine SELECT * FROM heart;
# 2024-04-26 22:04:35,291 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-26 22:04:35,298 INFO sqlalchemy.engine.Engine ROLLBACK
# Done!
#
#
# 2024-04-26 22:04:35,300 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-04-26 22:04:35,305 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("new_table")
# 2024-04-26 22:04:35,305 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-26 22:04:35,308 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("new_table")
# 2024-04-26 22:04:35,309 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-26 22:04:35,313 INFO sqlalchemy.engine.Engine
# CREATE TABLE new_table (
# 	id BIGINT,
# 	age BIGINT,
# 	sexe TEXT,
# 	type_douleur TEXT,
# 	pression BIGINT,
# 	cholester BIGINT,
# 	sucre TEXT,
# 	electro TEXT,
# 	taux_max BIGINT,
# 	angine TEXT,
# 	depression BIGINT,
# 	pic BIGINT,
# 	vaisseau TEXT,
# 	coeur TEXT
# )
#
#
# 2024-04-26 22:04:35,314 INFO sqlalchemy.engine.Engine [no key 0.00093s] ()
# 2024-04-26 22:04:35,407 INFO sqlalchemy.engine.Engine INSERT INTO new_table (id, age, sexe, type_douleur, pression, cholester, sucre, electro, taux_max, angine, depression, pic, vaisseau, coeur) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ? ...
# 2024-04-26 22:04:35,408 INFO sqlalchemy.engine.Engine [no key 0.00982s] (0, 70, 'masculin', 'D', 130, 322, 'A', 'C', 109, 'non', 24, 2, 'D', 'presence', 1, 67, 'feminin', 'C', 115, 564, 'A', 'C', 160, 'non', 16, 2, 'A', 'absence', 2, 57, 'masculin', 'B', 124, 261, 'A', 'A', 141, 'non', 3, 1, 'A', 'presence', 3, 64, 'masculin', 'D', 128, 263, 'A', 'A' ... 3680 parameters truncated ... 'A', 'A', 173, 'non', 0, 1, 'A', 'absence', 267, 56, 'feminin', 'B', 140, 294, 'A', 'C', 153, 'non', 13, 2, 'A', 'absence', 268, 57, 'masculin', 'D', 140, 192, 'A', 'A', 148, 'non', 4, 2, 'A', 'absence', 269, 67, 'masculin', 'D', 160, 286, 'A', 'C', 108, 'oui', 15, 2, 'D', 'presence')
# 2024-04-26 22:04:35,411 INFO sqlalchemy.engine.Engine COMMIT
# 270

# %%
df_sql
# Out:
#       id  age      sexe type_douleur  pression  cholester sucre electro  \
# 0      0   70  masculin            D       130        322     A       C
# 1      1   67   feminin            C       115        564     A       C
# 2      2   57  masculin            B       124        261     A       A
# 3      3   64  masculin            D       128        263     A       A
# 4      4   74   feminin            B       120        269     A       C
# ..   ...  ...       ...          ...       ...        ...   ...     ...
# 265  265   52  masculin            C       172        199     B       A
# 266  266   44  masculin            B       120        263     A       A
# 267  267   56   feminin            B       140        294     A       C
# 268  268   57  masculin            D       140        192     A       A
# 269  269   67  masculin            D       160        286     A       C
#
#      taux_max angine  depression  pic vaisseau     coeur
# 0         109    non          24    2        D  presence
# 1         160    non          16    2        A   absence
# 2         141    non           3    1        A  presence
# 3         105    oui           2    2        B   absence
# 4         121    oui           2    1        B   absence
# ..        ...    ...         ...  ...      ...       ...
# 265       162    non           5    1        A   absence
# 266       173    non           0    1        A   absence
# 267       153    non          13    2        A   absence
# 268       148    non           4    2        A   absence
# 269       108    oui          15    2        D  presence
#
# [270 rows x 14 columns]

# %% [markdown]
# ### Chunk size

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///data/heart.sqlite', echo=False)

for df_part in pd.read_sql("SELECT * FROM heart;", engine, chunksize=100):
    print(f"{df_part.shape = }")
# Out:
# df_part.shape = (100, 14)
# df_part.shape = (100, 14)
# df_part.shape = (70, 14)

# %% [markdown]
# ## Indexing // accessing the data

# %% [markdown]
# ### Single column

# %%
df['sexe']
# Out:
# 0      masculin
# 1       feminin
# 2      masculin
# 3      masculin
# 4       feminin
#          ...
# 265    masculin
# 266    masculin
# 267     feminin
# 268    masculin
# 269    masculin
# Name: sexe, Length: 270, dtype: object

# %%
df.sexe
# Out:
# 0      masculin
# 1       feminin
# 2      masculin
# 3      masculin
# 4       feminin
#          ...
# 265    masculin
# 266    masculin
# 267     feminin
# 268    masculin
# 269    masculin
# Name: sexe, Length: 270, dtype: object

# %% [markdown]
# ### Multiple columns

# %%
df[["sexe", "age"]]

# ! /!\ it needs to be in an array
# df["sexe", "age"] # -> throws an error
# Out:
#          sexe  age
# 0    masculin   70
# 1     feminin   67
# 2    masculin   57
# 3    masculin   64
# 4     feminin   74
# ..        ...  ...
# 265  masculin   52
# 266  masculin   44
# 267   feminin   56
# 268  masculin   57
# 269  masculin   67
#
# [270 rows x 2 columns]

# %% [markdown]
# ## Series object

# %%
type(df["age"])
# Out:
# pandas.core.series.Series

# %%
df['age'].head()
# Out:
# 0    70
# 1    67
# 2    57
# 3    64
# 4    74
# Name: age, dtype: int64

# %%
df['age'].tail()
# Out:
# 265    52
# 266    44
# 267    56
# 268    57
# 269    67
# Name: age, dtype: int64

# %%
df['age'].describe()
# Out:
# count    270.000000
# mean      54.433333
# std        9.109067
# min       29.000000
# 25%       48.000000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
df['sexe'].describe()
# Out:
# count          270
# unique           2
# top       masculin
# freq           183
# Name: sexe, dtype: object

# %%
df['age'].mean()
# Out:
# 54.43333333333333

# %%
df['type_douleur'].value_counts()
# Out:
# type_douleur
# D    129
# C     79
# B     42
# A     20
# Name: count, dtype: int64

# %%
# Series are vector. We can index it normally:

df['age'][0]
# Out:
# 70

# %%
df['age'][0:3]
# Out:
# 0    70
# 1    67
# 2    57
# Name: age, dtype: int64

# %%
df['age'].sort_values()
# Out:
# 214    29
# 174    34
# 138    34
# 224    35
# 81     35
#        ..
# 15     71
# 255    71
# 4      74
# 73     76
# 199    77
# Name: age, Length: 270, dtype: int64

# %%
df['age'].argsort()
# Out:
# 0      214
# 1      174
# 2      138
# 3      224
# 4       81
#       ...
# 265     15
# 266    255
# 267      4
# 268     73
# 269    199
# Name: age, Length: 270, dtype: int64

# %%
df['age'][df['age'].argsort()]
# Out:
# 214    29
# 174    34
# 138    34
# 224    35
# 81     35
#        ..
# 15     71
# 255    71
# 4      74
# 73     76
# 199    77
# Name: age, Length: 270, dtype: int64

# %% [markdown]
# ## Dataframe object

# %%
df.sort_values(by='age').head()
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 214   29  masculin            B       130        204     A       C       202
# 174   34  masculin            A       118        182     A       C       174
# 138   34   feminin            B       118        210     A       A       192
# 224   35   feminin            D       138        183     A       A       182
# 81    35  masculin            D       120        198     A       A       130
#
#     angine  depression  pic vaisseau     coeur
# 214    non           0    1        A   absence
# 174    non           0    1        A   absence
# 138    non           7    1        A   absence
# 224    non          14    1        A   absence
# 81     oui          16    2        A  presence

# %%
#passage par la librairie numpy
import numpy as np

#fonction call back
def operation(x):
    return(x.mean())

#appel de la fonction sur l'ensemble des colonnes du DataFrame#axis = 0 ==> chaque colonne sera transmise à la fonction operation()#la selection select_dtypes() permet d'exclure les variables non numériques

resultat = df.select_dtypes(exclude=['object']).apply(operation,axis=0)

resultat
# Out:
# age            54.433333
# pression      131.344444
# cholester     249.659259
# taux_max      149.677778
# depression     10.500000
# pic             1.585185
# dtype: float64

# %% [markdown]
# ## `.loc()` and `.iloc()`
#
# - `.loc()`: takes into account the inner indexing of the Series/Dataframe object.
# - `.iloc()`: takes into account the integer location of the data

# %% [markdown]
# ### On a Series

# %%
s = pd.Series(["a","b","c","d","e","f"], index=[49, 48, 47, 0, 1, 2]) 
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
s.loc[0]
# Out:
# 'd'

# %%
s.iloc[0]
# Out:
# 'a'

# %%
s.loc[0:1]
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:1]
# Out:
# 49    a
# dtype: object

# %% [markdown]
# ### `iloc()` on a dataframe

# %%
df.head(3)
# Out:
#    age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0   70  masculin            D       130        322     A       C       109
# 1   67   feminin            C       115        564     A       C       160
# 2   57  masculin            B       124        261     A       A       141
#
#   angine  depression  pic vaisseau     coeur
# 0    non          24    2        D  presence
# 1    non          16    2        A   absence
# 2    non           3    1        A  presence

# %%
df.iloc[0,0]
# Out:
# 70

# %%
df.iloc[-1,0]
# Out:
# 67

# %%
df.iloc[df.shape[0]-1,0]
# Out:
# 67

# %%
df.iloc[0:5,:]
# Out:
#    age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0   70  masculin            D       130        322     A       C       109
# 1   67   feminin            C       115        564     A       C       160
# 2   57  masculin            B       124        261     A       A       141
# 3   64  masculin            D       128        263     A       A       105
# 4   74   feminin            B       120        269     A       C       121
#
#   angine  depression  pic vaisseau     coeur
# 0    non          24    2        D  presence
# 1    non          16    2        A   absence
# 2    non           3    1        A  presence
# 3    oui           2    2        B   absence
# 4    oui           2    1        B   absence

# %%
colonnes = [1, 3, 4]
df.iloc[0:5,colonnes]
# Out:
#        sexe  pression  cholester
# 0  masculin       130        322
# 1   feminin       115        564
# 2  masculin       124        261
# 3  masculin       128        263
# 4   feminin       120        269

# %%
df.iloc[-5:,:]
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
#     angine  depression  pic vaisseau     coeur
# 265    non           5    1        A   absence
# 266    non           0    1        A   absence
# 267    non          13    2        A   absence
# 268    non           4    2        A   absence
# 269    oui          15    2        D  presence

# %%
df.iloc[0:5,0:2]
# Out:
#    age      sexe
# 0   70  masculin
# 1   67   feminin
# 2   57  masculin
# 3   64  masculin
# 4   74   feminin

# %%
df.iloc[0:5,[0,2,4]]
# Out:
#    age type_douleur  cholester
# 0   70            D        322
# 1   67            C        564
# 2   57            B        261
# 3   64            D        263
# 4   74            B        269

# %%
df.iloc[0:5,0:5:2]
# Out:
#    age type_douleur  cholester
# 0   70            D        322
# 1   67            C        564
# 2   57            B        261
# 3   64            D        263
# 4   74            B        269

# %% [markdown]
# ### `.loc()` on a dataframe

# %%
# We can index by column names

columns = ['age','sexe','coeur','taux_max']
df.loc[:10, columns]
# Out:
#     age      sexe     coeur  taux_max
# 0    70  masculin  presence       109
# 1    67   feminin   absence       160
# 2    57  masculin  presence       141
# 3    64  masculin   absence       105
# 4    74   feminin   absence       121
# 5    65  masculin   absence       140
# 6    56  masculin  presence       142
# 7    59  masculin  presence       142
# 8    60  masculin  presence       170
# 9    63   feminin  presence       154
# 10   59  masculin   absence       161

# %% [markdown]
# ## `.loc()` powerfull requests capabilities

# %%
df.loc[df['type_douleur']=="A",:]
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 13    61  masculin            A       134        234     A       A       145
# 18    64  masculin            A       110        211     A       C       144
# 19    40  masculin            A       140        199     A       A       178
# 37    59  masculin            A       160        273     A       C       125
# 63    60   feminin            A       150        240     A       A       171
# 64    63  masculin            A       145        233     B       C       150
# 85    42  masculin            A       148        244     A       C       178
# 87    59  masculin            A       178        270     A       C       145
# 118   66   feminin            A       150        226     A       A       114
# 143   51  masculin            A       125        213     A       C       125
# 158   56  masculin            A       120        193     A       C       162
# 160   38  masculin            A       120        231     A       A       182
# 169   65  masculin            A       138        282     B       C       174
# 170   69  masculin            A       160        234     B       C       131
# 174   34  masculin            A       118        182     A       C       174
# 198   69   feminin            A       140        239     A       A       151
# 205   52  masculin            A       152        298     B       A       178
# 210   59  masculin            A       170        288     A       C       159
# 228   58   feminin            A       150        283     B       C       162
# 229   52  masculin            A       118        186     A       C       190
#
#     angine  depression  pic vaisseau     coeur
# 13     non          26    2        C  presence
# 18     oui          18    2        A   absence
# 19     oui          14    1        A   absence
# 37     non           0    1        A  presence
# 63     non           9    1        A   absence
# 64     non          23    3        A   absence
# 85     non           8    1        C   absence
# 87     non          42    3        A   absence
# 118    non          26    3        A   absence
# 143    oui          14    1        B   absence
# 158    non          19    2        A   absence
# 160    oui          38    2        A  presence
# 169    non          14    2        B  presence
# 170    non           1    2        B   absence
# 174    non           0    1        A   absence
# 198    non          18    1        C   absence
# 205    non          12    2        A   absence
# 210    non           2    2        A  presence
# 228    non          10    1        A   absence
# 229    non           0    2        A   absence

# %% [markdown]
# ### Let's break down the query

# %%
df['type_douleur']=="A"
# Gives us a boolean Series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# Name: type_douleur, Length: 270, dtype: bool

# %%
(df['type_douleur']=="A").value_counts()
# Out:
# type_douleur
# False    250
# True      20
# Name: count, dtype: int64

# %%
boolean_series = df['type_douleur']=="A"

df.loc[boolean_series, :]
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 13    61  masculin            A       134        234     A       A       145
# 18    64  masculin            A       110        211     A       C       144
# 19    40  masculin            A       140        199     A       A       178
# 37    59  masculin            A       160        273     A       C       125
# 63    60   feminin            A       150        240     A       A       171
# 64    63  masculin            A       145        233     B       C       150
# 85    42  masculin            A       148        244     A       C       178
# 87    59  masculin            A       178        270     A       C       145
# 118   66   feminin            A       150        226     A       A       114
# 143   51  masculin            A       125        213     A       C       125
# 158   56  masculin            A       120        193     A       C       162
# 160   38  masculin            A       120        231     A       A       182
# 169   65  masculin            A       138        282     B       C       174
# 170   69  masculin            A       160        234     B       C       131
# 174   34  masculin            A       118        182     A       C       174
# 198   69   feminin            A       140        239     A       A       151
# 205   52  masculin            A       152        298     B       A       178
# 210   59  masculin            A       170        288     A       C       159
# 228   58   feminin            A       150        283     B       C       162
# 229   52  masculin            A       118        186     A       C       190
#
#     angine  depression  pic vaisseau     coeur
# 13     non          26    2        C  presence
# 18     oui          18    2        A   absence
# 19     oui          14    1        A   absence
# 37     non           0    1        A  presence
# 63     non           9    1        A   absence
# 64     non          23    3        A   absence
# 85     non           8    1        C   absence
# 87     non          42    3        A   absence
# 118    non          26    3        A   absence
# 143    oui          14    1        B   absence
# 158    non          19    2        A   absence
# 160    oui          38    2        A  presence
# 169    non          14    2        B  presence
# 170    non           1    2        B   absence
# 174    non           0    1        A   absence
# 198    non          18    1        C   absence
# 205    non          12    2        A   absence
# 210    non           2    2        A  presence
# 228    non          10    1        A   absence
# 229    non           0    2        A   absence

# %% [markdown]
# ### Multiple conditions

# %%
df.loc[(df['type_douleur']=="A") & (df['angine'] =="oui"),:]
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 18    64  masculin            A       110        211     A       C       144
# 19    40  masculin            A       140        199     A       A       178
# 143   51  masculin            A       125        213     A       C       125
# 160   38  masculin            A       120        231     A       A       182
#
#     angine  depression  pic vaisseau     coeur
# 18     oui          18    2        A   absence
# 19     oui          14    1        A   absence
# 143    oui          14    1        B   absence
# 160    oui          38    2        A  presence

# %%
# ! /!\ The () are necessary

# df.loc[df['type_douleur']=="A" & df['angine'] =="oui",:]

# %%
df.loc[(df['age'] < 45) & (df['sexe'] == "masculin") & (df['coeur'] =="presence"),:]
# Out:
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 40    40  masculin            D       152        223     A       A       181
# 47    44  masculin            D       110        197     A       C       177
# 50    42  masculin            D       136        315     A       A       125
# 81    35  masculin            D       120        198     A       A       130
# 147   40  masculin            D       110        167     A       C       114
# 160   38  masculin            A       120        231     A       A       182
# 182   41  masculin            D       110        172     A       C       158
# 193   35  masculin            D       126        282     A       C       156
# 231   39  masculin            D       118        219     A       A       140
# 237   43  masculin            D       120        177     A       C       120
# 252   44  masculin            D       112        290     A       C       153
#
#     angine  depression  pic vaisseau     coeur
# 40     non           0    1        A  presence
# 47     non           0    1        B  presence
# 50     oui          18    2        A  presence
# 81     oui          16    2        A  presence
# 147    oui          20    2        A  presence
# 160    oui          38    2        A  presence
# 182    non           0    1        A  presence
# 193    oui           0    1        A  presence
# 231    non          12    2        A  presence
# 237    oui          25    2        A  presence
# 252    non           0    1        B  presence

# %%
columns = ['age','sexe','coeur','taux_max']

df.loc[(df['age'] < 45) & (df['sexe'] == "masculin") & (df['coeur'] =="presence"),columns]
# Out:
#      age      sexe     coeur  taux_max
# 40    40  masculin  presence       181
# 47    44  masculin  presence       177
# 50    42  masculin  presence       125
# 81    35  masculin  presence       130
# 147   40  masculin  presence       114
# 160   38  masculin  presence       182
# 182   41  masculin  presence       158
# 193   35  masculin  presence       156
# 231   39  masculin  presence       140
# 237   43  masculin  presence       120
# 252   44  masculin  presence       153

# %% [markdown]
# ## Crosstab

# %%
pd.crosstab(df['sexe'],df['coeur'])
# Out:
# coeur     absence  presence
# sexe
# feminin        67        20
# masculin       83       100

# %% [markdown]
# ### Normalize

# %%
pd.crosstab(df['sexe'],df['coeur'],normalize='index')
# Out:
# coeur      absence  presence
# sexe
# feminin   0.770115  0.229885
# masculin  0.453552  0.546448

# %%
pd.crosstab(df['sexe'],df['coeur'],normalize='columns')
# Out:
# coeur      absence  presence
# sexe
# feminin   0.446667  0.166667
# masculin  0.553333  0.833333

# %%
pd.crosstab(df['sexe'],df['coeur'],normalize='all')
# Out:
# coeur      absence  presence
# sexe
# feminin   0.248148  0.074074
# masculin  0.307407  0.370370

# %% [markdown]
# ### Aggregate function

# %%
pd.crosstab(df['sexe'],df['coeur'],values=df['age'],aggfunc=pd.Series.median)
# Out:
# coeur     absence  presence
# sexe
# feminin      54.0      61.0
# masculin     52.0      57.5

# %% [markdown]
# ### More than 2 dimensions:

# %%
pd.crosstab(
    [df['sexe'], df['sucre']],
    df['coeur'],
    normalize='index'
)
# Out:
# coeur            absence  presence
# sexe     sucre
# feminin  A      0.802632  0.197368
#          B      0.545455  0.454545
# masculin A      0.428571  0.571429
#          B      0.586207  0.413793

# %% [markdown]
# ## Group by

# %%
# ✅
g = df.groupby('sexe')

# %%
type(g)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_for_group = g.get_group('masculin')
df_for_group.head()
# Out:
#    age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0   70  masculin            D       130        322     A       C       109
# 2   57  masculin            B       124        261     A       A       141
# 3   64  masculin            D       128        263     A       A       105
# 5   65  masculin            D       120        177     A       A       140
# 6   56  masculin            C       130        256     B       C       142
#
#   angine  depression  pic vaisseau     coeur
# 0    non          24    2        D  presence
# 2    non           3    1        A  presence
# 3    oui           2    2        B   absence
# 5    non           4    1        A   absence
# 6    oui           6    2        B  presence

# %%
type(g.get_group('masculin'))
# Out:
# pandas.core.frame.DataFrame

# %%
g.get_group('masculin').shape
# Out:
# (183, 13)

# %%
g.get_group('masculin')['age'].mean()
# Out:
# 53.84153005464481

# %%
g[['age','depression']].agg([pd.Series.mean,pd.Series.std])
# Out:
#                 age           depression
#                mean       std       mean        std
# sexe
# feminin   55.678161  9.626144   8.885057  11.332630
# masculin  53.841530  8.818189  11.267760  11.459408

# %%
for groupe in g:
    #groupe est un tuple
    print(f"{groupe[0] = }") #étiquette du groupe
    #accès à la variable 'age' du groupe concerné
    print(f"{pd.Series.mean(groupe[1]['age']) = }")
    print()
# Out:
# groupe[0] = 'feminin'
# pd.Series.mean(groupe[1]['age']) = 55.67816091954023
#
# groupe[0] = 'masculin'
# pd.Series.mean(groupe[1]['age']) = 53.84153005464481

# %% [markdown]
# ## Computed variables

# %% [markdown]
# ### Variable from another column

# %%
import numpy as np

taux_net = df['taux_max'] * np.log(df['age'])
taux_net
# Out:
# 0      463.085981
# 1      672.750819
# 2      570.070229
# 3      436.682724
# 4      520.791876
#           ...
# 265    640.101482
# 266    654.664807
# 267    615.878809
# 268    598.371588
# 269    454.106803
# Length: 270, dtype: float64

# %%
type(taux_net)
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (270, 13)

# %%
df_new = pd.concat([taux_net, df],axis=1)
df_new.shape
# Out:
# (270, 14)

# %%
df_new
# Out:
#               0  age      sexe type_douleur  pression  cholester sucre  \
# 0    463.085981   70  masculin            D       130        322     A
# 1    672.750819   67   feminin            C       115        564     A
# 2    570.070229   57  masculin            B       124        261     A
# 3    436.682724   64  masculin            D       128        263     A
# 4    520.791876   74   feminin            B       120        269     A
# ..          ...  ...       ...          ...       ...        ...   ...
# 265  640.101482   52  masculin            C       172        199     B
# 266  654.664807   44  masculin            B       120        263     A
# 267  615.878809   56   feminin            B       140        294     A
# 268  598.371588   57  masculin            D       140        192     A
# 269  454.106803   67  masculin            D       160        286     A
#
#     electro  taux_max angine  depression  pic vaisseau     coeur
# 0         C       109    non          24    2        D  presence
# 1         C       160    non          16    2        A   absence
# 2         A       141    non           3    1        A  presence
# 3         A       105    oui           2    2        B   absence
# 4         C       121    oui           2    1        B   absence
# ..      ...       ...    ...         ...  ...      ...       ...
# 265       A       162    non           5    1        A   absence
# 266       A       173    non           0    1        A   absence
# 267       C       153    non          13    2        A   absence
# 268       A       148    non           4    2        A   absence
# 269       C       108    oui          15    2        D  presence
#
# [270 rows x 14 columns]

# %%
df_new = df_new.rename(columns={0: "taux_net"})
df_new
# Out:
#        taux_net  age      sexe type_douleur  pression  cholester sucre  \
# 0    463.085981   70  masculin            D       130        322     A
# 1    672.750819   67   feminin            C       115        564     A
# 2    570.070229   57  masculin            B       124        261     A
# 3    436.682724   64  masculin            D       128        263     A
# 4    520.791876   74   feminin            B       120        269     A
# ..          ...  ...       ...          ...       ...        ...   ...
# 265  640.101482   52  masculin            C       172        199     B
# 266  654.664807   44  masculin            B       120        263     A
# 267  615.878809   56   feminin            B       140        294     A
# 268  598.371588   57  masculin            D       140        192     A
# 269  454.106803   67  masculin            D       160        286     A
#
#     electro  taux_max angine  depression  pic vaisseau     coeur
# 0         C       109    non          24    2        D  presence
# 1         C       160    non          16    2        A   absence
# 2         A       141    non           3    1        A  presence
# 3         A       105    oui           2    2        B   absence
# 4         C       121    oui           2    1        B   absence
# ..      ...       ...    ...         ...  ...      ...       ...
# 265       A       162    non           5    1        A   absence
# 266       A       173    non           0    1        A   absence
# 267       C       153    non          13    2        A   absence
# 268       A       148    non           4    2        A   absence
# 269       C       108    oui          15    2        D  presence
#
# [270 rows x 14 columns]

# %% [markdown]
# ### Broadcasting

# %%
# ✅
df['age'] * 365
# Out:
# 0      25550
# 1      24455
# 2      20805
# 3      23360
# 4      27010
#        ...
# 265    18980
# 266    16060
# 267    20440
# 268    20805
# 269    24455
# Name: age, Length: 270, dtype: int64

# %% [markdown]
# ### Variable ex-nihilo

# %%
sexe_code = pd.Series(np.zeros(df.shape[0]))
sexe_code.shape
# Out:
# (270,)

# %%
sexe_code[df['sexe']=='masculin'] = 1
sexe_code.value_counts()
# Out:
# 1.0    183
# 0.0     87
# Name: count, dtype: int64

# %%
sexe_code_bis = df['sexe'].eq('masculin').astype('int')
sexe_code_bis.value_counts()
# Out:
# sexe
# 1    183
# 0     87
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### fill df with NaN

# %%
import random

df_with_nan = pd.read_csv("data/heart.csv")

nb_cells = df_with_nan.shape[0] * df_with_nan.shape[1]
nb_nan = int(nb_cells * 0.05)

print(f"{nb_nan = }")
for _ in range(nb_nan):
    index = random.randint(0, df_with_nan.shape[0] - 1)
    column = random.randint(0, df_with_nan.shape[1] - 1)
    # print(f"Setting NaN on {index = } & {column = }")
    df_with_nan.iloc[index, column] = np.nan

df_with_nan.to_csv("./data/heart_with_nan.csv", index=False)
df_with_nan
# Out:
# nb_nan = 175
#       age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0    70.0  masculin            D     130.0      322.0     A       C     109.0
# 1    67.0   feminin            C     115.0      564.0     A     NaN     160.0
# 2    57.0  masculin            B       NaN      261.0     A       A     141.0
# 3    64.0  masculin            D     128.0      263.0     A     NaN     105.0
# 4    74.0   feminin            B     120.0      269.0     A       C     121.0
# ..    ...       ...          ...       ...        ...   ...     ...       ...
# 265  52.0  masculin            C     172.0      199.0     B       A     162.0
# 266  44.0  masculin            B     120.0      263.0     A       A     173.0
# 267  56.0   feminin            B     140.0      294.0     A       C     153.0
# 268  57.0  masculin            D     140.0      192.0     A       A     148.0
# 269  67.0  masculin            D     160.0      286.0     A       C     108.0
#
#     angine  depression  pic vaisseau     coeur
# 0      non         NaN  2.0        D  presence
# 1      non        16.0  2.0        A   absence
# 2      non         3.0  1.0        A       NaN
# 3      oui         2.0  2.0        B   absence
# 4      oui         2.0  1.0        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non         5.0  1.0        A   absence
# 266    non         0.0  1.0        A   absence
# 267    non        13.0  NaN        A   absence
# 268    non         4.0  2.0        A   absence
# 269    oui        15.0  2.0        D  presence
#
# [270 rows x 13 columns]

# %%
df_to_clean = pd.read_csv("data/heart_with_nan.csv")
df_to_clean
# Out:
#       age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0    70.0  masculin            D     130.0      322.0     A       C     109.0
# 1    67.0   feminin            C     115.0      564.0     A     NaN     160.0
# 2    57.0  masculin            B       NaN      261.0     A       A     141.0
# 3    64.0  masculin            D     128.0      263.0     A     NaN     105.0
# 4    74.0   feminin            B     120.0      269.0     A       C     121.0
# ..    ...       ...          ...       ...        ...   ...     ...       ...
# 265  52.0  masculin            C     172.0      199.0     B       A     162.0
# 266  44.0  masculin            B     120.0      263.0     A       A     173.0
# 267  56.0   feminin            B     140.0      294.0     A       C     153.0
# 268  57.0  masculin            D     140.0      192.0     A       A     148.0
# 269  67.0  masculin            D     160.0      286.0     A       C     108.0
#
#     angine  depression  pic vaisseau     coeur
# 0      non         NaN  2.0        D  presence
# 1      non        16.0  2.0        A   absence
# 2      non         3.0  1.0        A       NaN
# 3      oui         2.0  2.0        B   absence
# 4      oui         2.0  1.0        B   absence
# ..     ...         ...  ...      ...       ...
# 265    non         5.0  1.0        A   absence
# 266    non         0.0  1.0        A   absence
# 267    non        13.0  NaN        A   absence
# 268    non         4.0  2.0        A   absence
# 269    oui        15.0  2.0        D  presence
#
# [270 rows x 13 columns]

# %% [markdown]
# ### Drop NaN

# %%
df_to_clean.isna().sum()
# Out:
# age             13
# sexe            15
# type_douleur    12
# pression        15
# cholester       11
# sucre           11
# electro         14
# taux_max        16
# angine          11
# depression      10
# pic             13
# vaisseau        12
# coeur           16
# dtype: int64

# %%
df_droped = df_to_clean.dropna(
    axis=0,
    how="any",          # other option is "all"
)
df_droped
# Out:
#       age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 4    74.0   feminin            B     120.0      269.0     A       C     121.0
# 5    65.0  masculin            D     120.0      177.0     A       A     140.0
# 6    56.0  masculin            C     130.0      256.0     B       C     142.0
# 8    60.0  masculin            D     140.0      293.0     A       C     170.0
# 9    63.0   feminin            D     150.0      407.0     A       C     154.0
# ..    ...       ...          ...       ...        ...   ...     ...       ...
# 262  58.0  masculin            B     120.0      284.0     A       C     160.0
# 265  52.0  masculin            C     172.0      199.0     B       A     162.0
# 266  44.0  masculin            B     120.0      263.0     A       A     173.0
# 268  57.0  masculin            D     140.0      192.0     A       A     148.0
# 269  67.0  masculin            D     160.0      286.0     A       C     108.0
#
#     angine  depression  pic vaisseau     coeur
# 4      oui         2.0  1.0        B   absence
# 5      non         4.0  1.0        A   absence
# 6      oui         6.0  2.0        B  presence
# 8      non        12.0  2.0        C  presence
# 9      non        40.0  2.0        D  presence
# ..     ...         ...  ...      ...       ...
# 262    non        18.0  2.0        A  presence
# 265    non         5.0  1.0        A   absence
# 266    non         0.0  1.0        A   absence
# 268    non         4.0  2.0        A   absence
# 269    oui        15.0  2.0        D  presence
#
# [147 rows x 13 columns]

# %%
df_droped.isna().sum()
# Out:
# age             0
# sexe            0
# type_douleur    0
# pression        0
# cholester       0
# sucre           0
# electro         0
# taux_max        0
# angine          0
# depression      0
# pic             0
# vaisseau        0
# coeur           0
# dtype: int64

# %%
df_droped.shape
# Out:
# (147, 13)

# %%
df_to_clean.shape
# Out:
# (270, 13)

# %% [markdown]
# ### Fill NaN

# %%
df_static_filled = df_to_clean.fillna(
    value=0,
)

# %%
df_static_filled.isna().sum()
# Out:
# age             0
# sexe            0
# type_douleur    0
# pression        0
# cholester       0
# sucre           0
# electro         0
# taux_max        0
# angine          0
# depression      0
# pic             0
# vaisseau        0
# coeur           0
# dtype: int64

# %%
df_static_filled.head(10)
# Out:
#     age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0  70.0  masculin            D     130.0      322.0     A       C     109.0
# 1  67.0   feminin            C     115.0      564.0     A       0     160.0
# 2  57.0  masculin            B       0.0      261.0     A       A     141.0
# 3  64.0  masculin            D     128.0      263.0     A       0     105.0
# 4  74.0   feminin            B     120.0      269.0     A       C     121.0
# 5  65.0  masculin            D     120.0      177.0     A       A     140.0
# 6  56.0  masculin            C     130.0      256.0     B       C     142.0
# 7  59.0         0            D     110.0      239.0     A       C     142.0
# 8  60.0  masculin            D     140.0      293.0     A       C     170.0
# 9  63.0   feminin            D     150.0      407.0     A       C     154.0
#
#   angine  depression  pic vaisseau     coeur
# 0    non         0.0  2.0        D  presence
# 1    non        16.0  2.0        A   absence
# 2    non         3.0  1.0        A         0
# 3    oui         2.0  2.0        B   absence
# 4    oui         2.0  1.0        B   absence
# 5    non         4.0  1.0        A   absence
# 6    oui         6.0  2.0        B  presence
# 7    oui        12.0  2.0        0  presence
# 8    non        12.0  2.0        C  presence
# 9    non        40.0  2.0        D  presence

# %%
df_to_clean.dtypes
# Out:
# age             float64
# sexe             object
# type_douleur     object
# pression        float64
# cholester       float64
# sucre            object
# electro          object
# taux_max        float64
# angine           object
# depression      float64
# pic             float64
# vaisseau         object
# coeur            object
# dtype: object

# %%
colname_and_dtype = list(zip(df_to_clean.columns, df_to_clean.dtypes))
# print(f"{colname_and_dtype = }")

num_cols = []
str_cols = []
for colname, dtype in colname_and_dtype:
    if dtype == "object":
        str_cols.append(colname)
    else:
        num_cols.append(colname)

print(f"{num_cols = }")
print(f"{str_cols = }")
# Out:
# num_cols = ['age', 'pression', 'cholester', 'taux_max', 'depression', 'pic']
# str_cols = ['sexe', 'type_douleur', 'sucre', 'electro', 'angine', 'vaisseau', 'coeur']

# %%
df_dynamic_filled = df_to_clean.copy()

df_dynamic_filled[num_cols] = df_dynamic_filled[num_cols].fillna(
    value=df_to_clean[num_cols].median(),
)
df_dynamic_filled.head(10)
# Out:
#     age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0  70.0  masculin            D     130.0      322.0     A       C     109.0
# 1  67.0   feminin            C     115.0      564.0     A     NaN     160.0
# 2  57.0  masculin            B     130.0      261.0     A       A     141.0
# 3  64.0  masculin            D     128.0      263.0     A     NaN     105.0
# 4  74.0   feminin            B     120.0      269.0     A       C     121.0
# 5  65.0  masculin            D     120.0      177.0     A       A     140.0
# 6  56.0  masculin            C     130.0      256.0     B       C     142.0
# 7  59.0       NaN            D     110.0      239.0     A       C     142.0
# 8  60.0  masculin            D     140.0      293.0     A       C     170.0
# 9  63.0   feminin            D     150.0      407.0     A       C     154.0
#
#   angine  depression  pic vaisseau     coeur
# 0    non         8.0  2.0        D  presence
# 1    non        16.0  2.0        A   absence
# 2    non         3.0  1.0        A       NaN
# 3    oui         2.0  2.0        B   absence
# 4    oui         2.0  1.0        B   absence
# 5    non         4.0  1.0        A   absence
# 6    oui         6.0  2.0        B  presence
# 7    oui        12.0  2.0      NaN  presence
# 8    non        12.0  2.0        C  presence
# 9    non        40.0  2.0        D  presence

# %%
for str_col in str_cols:
    df_dynamic_filled[str_col] = df_dynamic_filled[str_col].fillna(
        value=df_to_clean[str_col].mode()[0],
    )
df_dynamic_filled.head(10)
# Out:
#     age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0  70.0  masculin            D     130.0      322.0     A       C     109.0
# 1  67.0   feminin            C     115.0      564.0     A       C     160.0
# 2  57.0  masculin            B     130.0      261.0     A       A     141.0
# 3  64.0  masculin            D     128.0      263.0     A       C     105.0
# 4  74.0   feminin            B     120.0      269.0     A       C     121.0
# 5  65.0  masculin            D     120.0      177.0     A       A     140.0
# 6  56.0  masculin            C     130.0      256.0     B       C     142.0
# 7  59.0  masculin            D     110.0      239.0     A       C     142.0
# 8  60.0  masculin            D     140.0      293.0     A       C     170.0
# 9  63.0   feminin            D     150.0      407.0     A       C     154.0
#
#   angine  depression  pic vaisseau     coeur
# 0    non         8.0  2.0        D  presence
# 1    non        16.0  2.0        A   absence
# 2    non         3.0  1.0        A   absence
# 3    oui         2.0  2.0        B   absence
# 4    oui         2.0  1.0        B   absence
# 5    non         4.0  1.0        A   absence
# 6    oui         6.0  2.0        B  presence
# 7    oui        12.0  2.0        A  presence
# 8    non        12.0  2.0        C  presence
# 9    non        40.0  2.0        D  presence
